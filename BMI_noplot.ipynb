# %% [markdown]
# # Esercizio BMI

# %%
import numpy as np
import pandas as pd

data = pd.read_csv(r'C:\Users\Marco Lombardini\Desktop\ComputerSociety\MaterialeEsercizi\Person_Gender_Height_Weight_Index.csv')

# %%
#Converto in m

data['Height_m'] = data['Height']/100

data
# Out:
#      Gender  Height  Weight  Index  Height_m
# 0      Male     174      96      4      1.74
# 1      Male     189      87      2      1.89
# 2    Female     185     110      4      1.85
# 3    Female     195     104      3      1.95
# 4      Male     149      61      3      1.49
# ..      ...     ...     ...    ...       ...
# 495  Female     150     153      5      1.50
# 496  Female     184     121      4      1.84
# 497  Female     141     136      5      1.41
# 498    Male     150      95      5      1.50
# 499    Male     173     131      5      1.73
#
# [500 rows x 5 columns]

# %%
#Calcolo la BMI

data['BMI'] = data['Weight']/ (data['Height_m']*2)

data
# Out:
#      Gender  Height  Weight  Index  Height_m        BMI
# 0      Male     174      96      4      1.74  27.586207
# 1      Male     189      87      2      1.89  23.015873
# 2    Female     185     110      4      1.85  29.729730
# 3    Female     195     104      3      1.95  26.666667
# 4      Male     149      61      3      1.49  20.469799
# ..      ...     ...     ...    ...       ...        ...
# 495  Female     150     153      5      1.50  51.000000
# 496  Female     184     121      4      1.84  32.880435
# 497  Female     141     136      5      1.41  48.226950
# 498    Male     150      95      5      1.50  31.666667
# 499    Male     173     131      5      1.73  37.861272
#
# [500 rows x 6 columns]

# %%
#Estraggo solo quello che mi interessa

bmi_ds = data[['Gender', 'Weight', 'Height']]

#bmi_ds = pd.DataFrame(data, columns= ['Gender', 'Weight', 'Height'])

bmi_ds
# Out:
#      Gender  Weight  Height
# 0      Male      96     174
# 1      Male      87     189
# 2    Female     110     185
# 3    Female     104     195
# 4      Male      61     149
# ..      ...     ...     ...
# 495  Female     153     150
# 496  Female     121     184
# 497  Female     136     141
# 498    Male      95     150
# 499    Male     131     173
#
# [500 rows x 3 columns]

# %%
#Salvo in locale il file
bmi_ds.to_csv(r'C:\Users\Marco Lombardini\Desktop\ComputerSociety\MaterialeEsercizi\Es2_bmi.csv')

# %%
#Aggiungo la colonna BMI a bmi_ds

bmi_ds['BMI'] = bmi_ds['Weight']/ (bmi_ds['Height']*2)

#Aggiusto la BMI

bmi_ds['BMI'] = bmi_ds['BMI']*100

# %%
bmi_ds
# Out:
#      Gender  Weight  Height        BMI
# 0      Male      96     174  27.586207
# 1      Male      87     189  23.015873
# 2    Female     110     185  29.729730
# 3    Female     104     195  26.666667
# 4      Male      61     149  20.469799
# ..      ...     ...     ...        ...
# 495  Female     153     150  51.000000
# 496  Female     121     184  32.880435
# 497  Female     136     141  48.226950
# 498    Male      95     150  31.666667
# 499    Male     131     173  37.861272
#
# [500 rows x 4 columns]

# %%
#Risalvo il file
bmi_ds.to_csv(r'C:\Users\Marco Lombardini\Desktop\ComputerSociety\MaterialeEsercizi\Es2_bmi.csv')

# %% [markdown]
# # Grafici BMI

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set(style="ticks", palette="bright")

# %%
#Grafico bar chart

seaborn.histplot(data= bmi_ds, binwidth=5, color="darkred", kde="true", element= "step")
plt.show()
